# %% [markdown]
# # Outline
# * Purpose: Multi-class image segmentation

# %% [markdown]
# # Importing modules

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils
import torch
from torch.utils.data import DataLoader

# %%
from multi_class_image_segmentation import CLASSES, COLOR_PALETTE, DEVICE, MaterialDataset, get_augmentation, get_list_img, get_preprocessing, visualize

# %% [markdown]
# # Defining variables

# %%
# ENCODER = 'efficientnet-b4'
# ENCODER = 'se_resnext50_32x4d'
# ENCODER = 'timm-mobilenetv3_large_075'
# ENCODER = 'vgg11'
ENCODER = 'vgg16'
# ENCODER = 'vgg19'
# ENCODER = 'vgg19_bn'

ENCODER_WEIGHTS = 'imagenet'

ACTIVATION = 'softmax2d'
# ACTIVATION = 'sigmoid'

BATCH_SIZE = 8

PREDICT_CLASS = [
    'background',
    'asufalt',
    'bigrock',
    'glass',
    'renga',
    'rockmid',
    'rocksmall',
]

# %% [markdown]
# # Preparing data

# %%
# encoderに合わせた前処理の取得
preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# データ周りを格納する辞書
data_info = {}
rootpath = r'./data/train/'

for phase in ['train', 'val']:
    data_info[f'{phase}_img_path'] = get_list_img(f'{rootpath}/images/division-1')
    data_info[f'{phase}_mask_path'] = get_list_img(f'{rootpath}/masks/division-1', ext='png')
    
    # Dataset
    data_info[f'{phase}_dataset'] = MaterialDataset(
            data_info[f'{phase}_img_path'], 
            data_info[f'{phase}_mask_path'], 
            classes=PREDICT_CLASS,
            augmentation=get_augmentation(phase), 
            preprocessing=get_preprocessing(preprocessing_fn)
            )

    # DataLoader
    shuffle = True if phase == 'train' else False
    data_info[f'{phase}_dataloader'] = DataLoader(
        data_info[f'{phase}_dataset'], 
        batch_size=BATCH_SIZE, 
        shuffle=shuffle)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/albumentations/imgaug/transforms.py:261: FutureWarning: IAAAdditiveGaussianNoise is deprecated. Please use GaussNoise instead
#   warnings.warn("IAAAdditiveGaussianNoise is deprecated. Please use GaussNoise instead", FutureWarning)
# /home/vscode/.local/lib/python3.11/site-packages/albumentations/imgaug/transforms.py:384: FutureWarning: This IAAPerspective is deprecated. Please use Perspective instead
#   warnings.warn("This IAAPerspective is deprecated. Please use Perspective instead", FutureWarning)
# /home/vscode/.local/lib/python3.11/site-packages/albumentations/augmentations/transforms.py:1258: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /home/vscode/.local/lib/python3.11/site-packages/albumentations/imgaug/transforms.py:231: FutureWarning: IAASharpen is deprecated. Please use Sharpen instead
#   warnings.warn("IAASharpen is deprecated. Please use Sharpen instead", FutureWarning)
# /home/vscode/.local/lib/python3.11/site-packages/albumentations/augmentations/transforms.py:1284: FutureWarning: RandomContrast has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %%
for i in range(100):
    image, mask = data_info['train_dataset'][i]
    mask = np.argmax(mask, axis=0)
    mask = Image.fromarray(np.uint8(mask), mode='P')
    mask.putpalette(COLOR_PALETTE)
    visualize(image=image.transpose(1,2,0), mask=mask)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in range(100):
# ----> 2     image, mask = data_info['train_dataset'][i]
#       3     mask = np.argmax(mask, axis=0)
#       4     mask = Image.fromarray(np.uint8(mask), mode='P')
#
# File /workspaces/unet/multi_class_image_segmentation.py:48, in MaterialDataset.__getitem__(self, i)
#      47 def __getitem__(self, i):
# ---> 48     image = Image.open(self.images_path[i])
#      49     image = crop_to_square(image)
#      50     #  image = image.resize((128,128), Image.ANTIALIAS)
#
# IndexError: list index out of range

# %% [markdown]
# # Training model

# %%
# model = smp.Unet(
#     encoder_name=ENCODER, 
#     encoder_weights=ENCODER_WEIGHTS, 
#     classes=len(PREDICT_CLASS), 
#     activation=ACTIVATION,
# )

# model = smp.UnetPlusPlus(
#     encoder_name=ENCODER, 
#     encoder_weights=ENCODER_WEIGHTS, 
#     classes=len(PREDICT_CLASS), 
#     activation=ACTIVATION,
# )

# model = smp.FPN(
#     encoder_name=ENCODER, 
#     encoder_weights=ENCODER_WEIGHTS, 
#     classes=len(CLASSES), 
#     activation=ACTIVATION,
# )

model = smp.PSPNet(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
    classes=len(CLASSES), 
    activation=ACTIVATION,
)

# model = smp.DeepLabV3Plus(
#     encoder_name=ENCODER, 
#     encoder_weights=ENCODER_WEIGHTS, 
#     classes=len(CLASSES), 
#     activation=ACTIVATION,
# )
# model = torch.hub.load('pytorch/vision:v0.10.0', 'deeplabv3_resnet50', pretrained=True)

# %%
loss = smp.utils.losses.DiceLoss()
metrics = [smp.utils.metrics.IoU(threshold=0.5)]
optimizer = torch.optim.Adam([dict(params=model.parameters(), lr=0.0001)])

train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE
)

valid_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    device=DEVICE
)

# %%
max_iter = 40
patience = 10

max_score = 0
best_model_path = 'data/models/best_model.pth'
last_model_path = 'data/models/last_model.pth'

for i in range(max_iter):
    print(f"Epoch: {i+1}")
    train_logs = train_epoch.run(data_info["train_dataloader"])
    valid_logs = valid_epoch.run(data_info["val_dataloader"])
    
    # IoUスコアが最高値が更新されればモデルを保存
    if max_score < valid_logs["iou_score"]:
        max_score = valid_logs["iou_score"]
        torch.save(model, best_model_path)
        print("Model saved!")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        print(f"not improve for {early_stop_counter}Epoch")
        if early_stop_counter==patience:
            print(f"early stop. Max Score {max_score}")
            break

    # 適当なタイミングでlearning rateの変更
    if i == 25:
        optimizer.param_groups[0]["lr"] = 1e-5
        print("Decrease decoder learning rate to 1e-5")
    torch.save(model, last_model_path)
# Out:
# Epoch: 1
# train: 100%|██████████| 3/3 [00:19<00:00,  6.48s/it, dice_loss - 0.9552, iou_score - 0.06935]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.13it/s, dice_loss - 0.7155, iou_score - 0.1665]
# Model saved!
# Epoch: 2
# train: 100%|██████████| 3/3 [00:19<00:00,  6.47s/it, dice_loss - 0.9182, iou_score - 0.1375]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.22it/s, dice_loss - 0.6122, iou_score - 0.29]
# Model saved!
# Epoch: 3
# train: 100%|██████████| 3/3 [00:19<00:00,  6.41s/it, dice_loss - 0.9272, iou_score - 0.1282]
# valid: 100%|██████████| 3/3 [00:01<00:00,  1.99it/s, dice_loss - 0.506, iou_score - 0.4532]
# Model saved!
# Epoch: 4
# train: 100%|██████████| 3/3 [00:19<00:00,  6.34s/it, dice_loss - 0.9133, iou_score - 0.1616]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.08it/s, dice_loss - 0.4555, iou_score - 0.4787]
# Model saved!
# Epoch: 5
# train: 100%|██████████| 3/3 [00:19<00:00,  6.38s/it, dice_loss - 0.8976, iou_score - 0.1721]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.19it/s, dice_loss - 0.495, iou_score - 0.44]
# not improve for 1Epoch
# Epoch: 6
# train: 100%|██████████| 3/3 [00:18<00:00,  6.30s/it, dice_loss - 0.8812, iou_score - 0.1786]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.21it/s, dice_loss - 0.5163, iou_score - 0.4157]
# not improve for 2Epoch
# Epoch: 7
# train: 100%|██████████| 3/3 [00:19<00:00,  6.36s/it, dice_loss - 0.8689, iou_score - 0.1913]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.08it/s, dice_loss - 0.5069, iou_score - 0.4309]
# not improve for 3Epoch
# Epoch: 8
# train: 100%|██████████| 3/3 [00:19<00:00,  6.34s/it, dice_loss - 0.8812, iou_score - 0.1835]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.11it/s, dice_loss - 0.4694, iou_score - 0.4594]
# not improve for 4Epoch
# Epoch: 9
# train: 100%|██████████| 3/3 [00:18<00:00,  6.15s/it, dice_loss - 0.8494, iou_score - 0.2205]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.21it/s, dice_loss - 0.406, iou_score - 0.504]
# Model saved!
# Epoch: 10
# train: 100%|██████████| 3/3 [00:18<00:00,  6.18s/it, dice_loss - 0.8753, iou_score - 0.2042]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.26it/s, dice_loss - 0.4912, iou_score - 0.4469]
# not improve for 1Epoch
# Epoch: 11
# train: 100%|██████████| 3/3 [00:18<00:00,  6.22s/it, dice_loss - 0.8675, iou_score - 0.1837]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.17it/s, dice_loss - 0.4985, iou_score - 0.442]
# not improve for 2Epoch
# Epoch: 12
# train: 100%|██████████| 3/3 [00:18<00:00,  6.23s/it, dice_loss - 0.8597, iou_score - 0.1942]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.23it/s, dice_loss - 0.4731, iou_score - 0.45]
# not improve for 3Epoch
# Epoch: 13
# train: 100%|██████████| 3/3 [00:18<00:00,  6.27s/it, dice_loss - 0.8531, iou_score - 0.1828]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.15it/s, dice_loss - 0.3515, iou_score - 0.5434]
# Model saved!
# Epoch: 14
# train: 100%|██████████| 3/3 [00:18<00:00,  6.14s/it, dice_loss - 0.8306, iou_score - 0.2181]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.26it/s, dice_loss - 0.4011, iou_score - 0.5023]
# not improve for 1Epoch
# Epoch: 15
# train: 100%|██████████| 3/3 [00:18<00:00,  6.14s/it, dice_loss - 0.8668, iou_score - 0.1649]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.19it/s, dice_loss - 0.4142, iou_score - 0.4947]
# not improve for 2Epoch
# Epoch: 16
# train: 100%|██████████| 3/3 [00:18<00:00,  6.13s/it, dice_loss - 0.8775, iou_score - 0.1488]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.11it/s, dice_loss - 0.3822, iou_score - 0.5176]
# not improve for 3Epoch
# Epoch: 17
# train: 100%|██████████| 3/3 [00:18<00:00,  6.18s/it, dice_loss - 0.8582, iou_score - 0.1598]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.24it/s, dice_loss - 0.3286, iou_score - 0.5822]
# Model saved!
# Epoch: 18
# train: 100%|██████████| 3/3 [00:18<00:00,  6.19s/it, dice_loss - 0.8469, iou_score - 0.1718]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.13it/s, dice_loss - 0.2764, iou_score - 0.6559]
# Model saved!
# Epoch: 19
# train: 100%|██████████| 3/3 [00:18<00:00,  6.20s/it, dice_loss - 0.8317, iou_score - 0.2295]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, dice_loss - 0.2913, iou_score - 0.6304]
# not improve for 1Epoch
# Epoch: 20
# train: 100%|██████████| 3/3 [00:18<00:00,  6.05s/it, dice_loss - 0.8399, iou_score - 0.2069]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.23it/s, dice_loss - 0.275, iou_score - 0.6678]
# Model saved!
# Epoch: 21
# train: 100%|██████████| 3/3 [00:18<00:00,  6.15s/it, dice_loss - 0.8541, iou_score - 0.2074]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, dice_loss - 0.2794, iou_score - 0.5975]
# not improve for 1Epoch
# Epoch: 22
# train: 100%|██████████| 3/3 [00:18<00:00,  6.14s/it, dice_loss - 0.8298, iou_score - 0.2489]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.16it/s, dice_loss - 0.351, iou_score - 0.5349]
# not improve for 2Epoch
# Epoch: 23
# train: 100%|██████████| 3/3 [00:18<00:00,  6.08s/it, dice_loss - 0.8484, iou_score - 0.2268]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.08it/s, dice_loss - 0.3275, iou_score - 0.5565]
# not improve for 3Epoch
# Epoch: 24
# train: 100%|██████████| 3/3 [00:18<00:00,  6.12s/it, dice_loss - 0.8343, iou_score - 0.2062]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.05it/s, dice_loss - 0.2693, iou_score - 0.6086]
# not improve for 4Epoch
# Epoch: 25
# train: 100%|██████████| 3/3 [00:18<00:00,  6.14s/it, dice_loss - 0.815, iou_score - 0.2098]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.23it/s, dice_loss - 0.3361, iou_score - 0.54]
# not improve for 5Epoch
# Epoch: 26
# train: 100%|██████████| 3/3 [00:18<00:00,  6.16s/it, dice_loss - 0.8526, iou_score - 0.1715]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.18it/s, dice_loss - 0.3409, iou_score - 0.5349]
# not improve for 6Epoch
# Decrease decoder learning rate to 1e-5
# Epoch: 27
# train: 100%|██████████| 3/3 [00:18<00:00,  6.17s/it, dice_loss - 0.8278, iou_score - 0.2386]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.18it/s, dice_loss - 0.3375, iou_score - 0.5396]
# not improve for 7Epoch
# Epoch: 28
# train: 100%|██████████| 3/3 [00:18<00:00,  6.20s/it, dice_loss - 0.8297, iou_score - 0.2179]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.18it/s, dice_loss - 0.3337, iou_score - 0.5449]
# not improve for 8Epoch
# Epoch: 29
# train: 100%|██████████| 3/3 [00:18<00:00,  6.24s/it, dice_loss - 0.8413, iou_score - 0.2008]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.23it/s, dice_loss - 0.3266, iou_score - 0.5503]
# not improve for 9Epoch
# Epoch: 30
# train: 100%|██████████| 3/3 [00:18<00:00,  6.18s/it, dice_loss - 0.8356, iou_score - 0.2078]
# valid: 100%|██████████| 3/3 [00:01<00:00,  2.23it/s, dice_loss - 0.3195, iou_score - 0.5563]
# not improve for 10Epoch
# early stop. Max Score 0.6678462872902553

# %% [markdown]
# # Inferring

# %%
best_model = torch.load(best_model_path)
# best_model = torch.load(last_model_path)
# best_model.eval()

# %%
test_path = 'data/test'

test_dataset = MaterialDataset(
    get_list_img(f'{test_path}/images/division-1'), 
    get_list_img(f'{test_path}/masks/division-1', 'png'), 
    classes=PREDICT_CLASS,
    # augmentation=get_augmentation(phase), 
    preprocessing=get_preprocessing(preprocessing_fn),
)

# %%
for i in range(10):
    img, mask = test_dataset[i]
    
    fig, ax = plt.subplots(1, 3, tight_layout=True)
    ax[0].imshow(img.transpose(1,2,0))
    
    mask = np.argmax(mask, axis=0)
    mask = Image.fromarray(np.uint8(mask), mode="P")
    mask.putpalette(COLOR_PALETTE)
    ax[1].imshow(mask)
    
    x = torch.tensor(img).unsqueeze(0) # 推論のためミニバッチ化：torch.Size([1, 3, 128, 128])
    y = best_model(x.to(DEVICE))
    y = y[0].cpu().detach().numpy()
    y = np.argmax(y, axis=0)
    predict_class_img = Image.fromarray(np.uint8(y), mode="P")
    predict_class_img.putpalette(COLOR_PALETTE)
    ax[2].imshow(predict_class_img)
    
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 for i in range(10):
# ----> 2     img, mask = test_dataset[i]
#       4     fig, ax = plt.subplots(1, 3, tight_layout=True)
#       5     ax[0].imshow(img.transpose(1,2,0))
#
# File /workspaces/unet/multi_class_image_segmentation.py:48, in MaterialDataset.__getitem__(self, i)
#      47 def __getitem__(self, i):
# ---> 48     image = Image.open(self.images_path[i])
#      49     image = crop_to_square(image)
#      50     #  image = image.resize((128,128), Image.ANTIALIAS)
#
# IndexError: list index out of range
